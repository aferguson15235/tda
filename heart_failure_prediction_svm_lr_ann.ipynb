# %%
## import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score
import warnings

## neural network library
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Input
from mlxtend.plotting import plot_confusion_matrix
import pickle
import joblib

# %%
# Suppress all DeprecationWarnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
## load data
dfheart = pd.read_csv("heart_failure_clinical_records_dataset.csv")
dfheart.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
## info for missing value and data type
dfheart.info()

## all variables contain no null value but complete
## all variable values are numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
## Basic statistics summary of all variables in dataset
dfheart.describe()

## Age group covering from 40 to 95, missing youth
## mean Sex > 0.5, 14.88% more male interviewees
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
fig, ax = plt.subplots(2, 3, figsize=(14, 10))

# First row
sns.countplot(ax=ax[0, 0], data=dfheart, x="anaemia", hue="DEATH_EVENT", palette=["blue", "red"])
ax[0, 0].legend(['Alive', 'Dead'])
ax[0, 0].bar_label(ax[0, 0].containers[0])
ax[0, 0].bar_label(ax[0, 0].containers[1])

sns.countplot(ax=ax[0, 1], data=dfheart, x="diabetes", hue="DEATH_EVENT", palette=["blue", "red"])
ax[0, 1].legend(['Alive', 'Dead'])
ax[0, 1].bar_label(ax[0, 1].containers[0])
ax[0, 1].bar_label(ax[0, 1].containers[1])

sns.countplot(ax=ax[0, 2], data=dfheart, x="high_blood_pressure", hue="DEATH_EVENT", palette=["blue", "red"])
ax[0, 2].legend(['Alive', 'Dead'])
ax[0, 2].bar_label(ax[0, 2].containers[0])
ax[0, 2].bar_label(ax[0, 2].containers[1])

# Second row
sns.countplot(ax=ax[1, 0], data=dfheart, x="DEATH_EVENT", hue="DEATH_EVENT", palette=["blue", "red"], legend=False)
ax[1, 0].bar_label(ax[1, 0].containers[0])
ax[1, 0].bar_label(ax[1, 0].containers[1])

sns.countplot(ax=ax[1, 1], data=dfheart, x="sex", hue="DEATH_EVENT", palette=["blue", "red"])
ax[1, 1].legend(['Alive', 'Dead'])
ax[1, 1].bar_label(ax[1, 1].containers[0])
ax[1, 1].bar_label(ax[1, 1].containers[1])

sns.countplot(ax=ax[1, 2], data=dfheart, x="smoking", hue="DEATH_EVENT", palette=["blue", "red"])
ax[1, 2].legend(['Alive', 'Dead'])
ax[1, 2].bar_label(ax[1, 2].containers[0])
ax[1, 2].bar_label(ax[1, 2].containers[1])

plt.tight_layout()  
plt.show()

# %%
## Correlation Matrix
mt = dfheart.corr()
print(mt)
fig, ax=plt.subplots(figsize=(16,9))
sns.heatmap(mt, annot=True, square=False)
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.101012           0.060098             0.093289
# anaemia                  -0.012729           0.031557             0.038182
# creatinine_phosphokinase -0.009639          -0.044080            -0.070590
# diabetes                  1.000000          -0.004850            -0.012732
# ejection_fraction        -0.004850           1.000000             0.024445
# high_blood_pressure      -0.012732           0.024445             1.000000
# platelets                 0.092193           0.072177             0.049963
# serum_creatinine         -0.046975          -0.011302            -0.004935
# serum_sodium             -0.089551           0.175902             0.037109
# sex                      -0.157730          -0.148386            -0.104615
# smoking                  -0.147173          -0.067315            -0.055711
# time                      0.033726           0.041729            -0.196439
# DEATH_EVENT              -0.001943          -0.268603             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052354          0.159187     -0.045966  0.065430
# anaemia                   -0.043786          0.052174      0.041882 -0.094769
# creatinine_phosphokinase   0.024463         -0.016408      0.059550  0.079791
# diabetes                   0.092193         -0.046975     -0.089551 -0.157730
# ejection_fraction          0.072177         -0.011302      0.175902 -0.148386
# high_blood_pressure        0.049963         -0.004935      0.037109 -0.104615
# platelets                  1.000000         -0.041198      0.062125 -0.125120
# serum_creatinine          -0.041198          1.000000     -0.189095  0.006970
# serum_sodium               0.062125         -0.189095      1.000000 -0.027566
# sex                       -0.125120          0.006970     -0.027566  1.000000
# smoking                    0.028234         -0.027414      0.004813  0.445892
# time                       0.010514         -0.149315      0.087640 -0.015608
# DEATH_EVENT               -0.049139          0.294278     -0.195204 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.018668 -0.224068     0.253729
# anaemia                  -0.107290 -0.141414     0.066270
# creatinine_phosphokinase  0.002421 -0.009346     0.062728
# diabetes                 -0.147173  0.033726    -0.001943
# ejection_fraction        -0.067315  0.041729    -0.268603
# high_blood_pressure      -0.055711 -0.196439     0.079351
# platelets                 0.028234  0.010514    -0.049139
# serum_creatinine         -0.027414 -0.149315     0.294278
# serum_sodium              0.004813  0.087640    -0.195204
# sex                       0.445892 -0.015608    -0.004316
# smoking                   1.000000 -0.022839    -0.012623
# time                     -0.022839  1.000000    -0.526964
# DEATH_EVENT              -0.012623 -0.526964     1.000000
# <Axes: >

# %%
## Visualise the population age distribution between the alive and the dead
plt.figure(figsize=(16,8))
ax = sns.histplot(dfheart["age"][dfheart.DEATH_EVENT == 0], color="blue", kde=True), sns.histplot(dfheart["age"][dfheart.DEATH_EVENT == 1], color="red", kde=True)
plt.legend(['Alive', 'Dead'])
plt.title('Age Distribution for Population Alive and Dead')

## Older people are more likely to be dead than alive, the younger ones are in opposite situation
## however, the age data in general is not normally distributed given that it is right-skewed with big left tail, due to missing youth population data and extremely old outliers.
# Out:
# Text(0.5, 1.0, 'Age Distribution for Population Alive and Dead')

# %%
## Visualise the population follow-up time distribution between the alive and the dead
plt.figure(figsize=(16,8))
ax = sns.histplot(dfheart["time"][dfheart.DEATH_EVENT == 0], color="blue", kde=True), sns.histplot(dfheart["time"][dfheart.DEATH_EVENT == 1], color="red", kde=True)
plt.legend(['Alive', 'Dead'])
plt.title('Follow-up Time Distribution for Population Alive and Dead')

## Death cases are more likely to be rapid.
# Out:
# Text(0.5, 1.0, 'Follow-up Time Distribution for Population Alive and Dead')

# %%
# Assuming dfheart is your DataFrame
fig, ax = plt.subplots(3, 3, figsize=(20, 12))  # Increased figure size for more room

# Swarmplot with adjusted marker size and reduced overlap
sns.stripplot(ax=ax[0, 0], x=dfheart["DEATH_EVENT"], y=dfheart["age"], color="black", alpha=0.7, size=2)  # Use stripplot and reduced size
sns.boxenplot(ax=ax[0, 0], x=dfheart["DEATH_EVENT"], y=dfheart["age"])

sns.stripplot(ax=ax[0, 1], x=dfheart["DEATH_EVENT"], y=dfheart["creatinine_phosphokinase"], color="black", alpha=0.7, size=2)
sns.boxenplot(ax=ax[0, 1], x=dfheart["DEATH_EVENT"], y=dfheart["creatinine_phosphokinase"])

sns.stripplot(ax=ax[0, 2], x=dfheart["DEATH_EVENT"], y=dfheart["ejection_fraction"], color="black", alpha=0.7, size=2)
sns.boxenplot(ax=ax[0, 2], x=dfheart["DEATH_EVENT"], y=dfheart["ejection_fraction"])

sns.stripplot(ax=ax[1, 0], x=dfheart["DEATH_EVENT"], y=dfheart["platelets"], color="black", alpha=0.7, size=2)
sns.boxenplot(ax=ax[1, 0], x=dfheart["DEATH_EVENT"], y=dfheart["platelets"])

sns.stripplot(ax=ax[1, 1], x=dfheart["DEATH_EVENT"], y=dfheart["serum_creatinine"], color="black", alpha=0.7, size=2)
sns.boxenplot(ax=ax[1, 1], x=dfheart["DEATH_EVENT"], y=dfheart["serum_creatinine"])

sns.stripplot(ax=ax[1, 2], x=dfheart["DEATH_EVENT"], y=dfheart["serum_sodium"], color="black", alpha=0.7, size=2)
sns.boxenplot(ax=ax[1, 2], x=dfheart["DEATH_EVENT"], y=dfheart["serum_sodium"])

# Use a sample of the data to reduce plot congestion for time
sns.stripplot(ax=ax[2, 1], x=dfheart["DEATH_EVENT"], y=dfheart["time"], color="black", alpha=0.7, size=2, data=dfheart.sample(100))
sns.boxenplot(ax=ax[2, 1], x=dfheart["DEATH_EVENT"], y=dfheart["time"])

plt.tight_layout()  # Adjust layout for better spacing between subplots
plt.show()

# %%
## defining independent and dependent variables
x=dfheart.drop(["DEATH_EVENT"],axis=1)
y=dfheart["DEATH_EVENT"]

# %%
scaler = StandardScaler()

# Fit and transform the data
scale_x = scaler.fit_transform(x)


# Save the scaler to a file using pickle
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("Scaler has been re-saved successfully!")
# Out:
# Scaler has been re-saved successfully!

# %%
print(type(scaler))
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>

# %%
## train-test split 
x_train, x_test, y_train,y_test = train_test_split(scale_x,y,test_size=0.4,random_state=23)

# %%
# Instantiating the SVM algorithm 
#Create a SVM Classifier
svm_linear = svm.SVC(kernel='linear')
svm_sigmoid = svm.SVC(kernel='sigmoid') 
svm_rbf = svm.SVC(kernel='rbf') 

# Fitting the model 
svm_linear.fit(x_train, y_train)
svm_sigmoid.fit(x_train, y_train)
svm_rbf.fit(x_train, y_train)

# Predicting the test variables
y_pred_linear = svm_linear.predict(x_test)
y_pred_sigmoid = svm_sigmoid.predict(x_test)
y_pred_rbf = svm_rbf.predict(x_test)

# Getting the score 
print("Linear Kernel Accuracy:",metrics.accuracy_score(y_test, y_pred_linear))
print("Sigmoid kernel Accuracy:",metrics.accuracy_score(y_test, y_pred_sigmoid))
print("rbf kernelAccuracy:",metrics.accuracy_score(y_test, y_pred_rbf))
# Out:
# Linear Kernel Accuracy: 0.7916666666666666
# Sigmoid kernel Accuracy: 0.8083333333333333
# rbf kernelAccuracy: 0.7833333333333333

# %%
# Save the svm model
with open('svm.pkl', 'wb') as f:
    pickle.dump(svm_linear, f)

print("model has been re-saved successfully!")
# Out:
# model has been re-saved successfully!

# %%
## make a dataframe prediction for linear kernel
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_linear})
# Out:
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          1
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
## make a dataframe prediction for linear kernel
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_sigmoid})
# Out:
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          0
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
## make a dataframe prediction for linear kernel
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_rbf})
# Out:
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          1
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
## confussion matrix for the kernels
conf_mat_linear = confusion_matrix(y_test, y_pred_linear)
conf_mat_sigmoid = confusion_matrix(y_test, y_pred_sigmoid)
conf_mat_rbf = confusion_matrix(y_test, y_pred_rbf)

print(conf_mat_linear)
print(conf_mat_sigmoid)
print(conf_mat_rbf)
# Out:
# [[70 12]
#  [13 25]]
# [[75  7]
#  [16 22]]
# [[74  8]
#  [18 20]]

# %%
sns.heatmap(conf_mat_linear, annot=True, fmt='.0f')
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred_linear))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85        82
#            1       0.68      0.66      0.67        38
#
#     accuracy                           0.79       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.79      0.79      0.79       120

# %%
auc = roc_auc_score(y_test, y_pred_linear)
print('AUC: %f' %auc)
# Out:
# AUC: 0.755777

# %%
fpr, tpr = roc_curve(y_test, y_pred_linear)[0:2]

plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()

# %%
# Build a logiReg Model
model_lr = LogisticRegression(random_state=0, solver='lbfgs', max_iter=100)
model_lr.fit(x_train, y_train)
y_pred_lr = model_lr.predict(x_test)
print(model_lr.coef_)
## accuracy score
print(accuracy_score(y_test,y_pred_lr))
## confusion matrix
mat = confusion_matrix(y_test, y_pred_lr)
print(mat)
print(classification_report(y_test,y_pred_lr))
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr})
# Out:
# [[ 0.5559466   0.08194236  0.3764469   0.1398406  -0.85338447  0.04650698
#   -0.34281474  1.01912125 -0.2731351  -0.41714128 -0.17910547 -1.34243291]]
# 0.775
# [[71 11]
#  [16 22]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84        82
#            1       0.67      0.58      0.62        38
#
#     accuracy                           0.78       120
#    macro avg       0.74      0.72      0.73       120
# weighted avg       0.77      0.78      0.77       120
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          1
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
fpr, tpr = roc_curve(y_test, y_pred_lr)[0:2]

plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()

# %%
## Neural Network
## initialise the NN
model = Sequential()

##set up the layers
model.add(Input(shape=(12,)))
## input layer
model.add(Dense(units= 50, kernel_initializer= 'uniform', activation = 'relu'))
## hidden layer 1 
model.add(Dense(units= 20, kernel_initializer= 'uniform', activation = 'relu'))
##regularization 1
model.add(Dropout(0.4))
## hidden layer 2
model.add(Dense(units= 4, kernel_initializer= 'uniform', activation = 'relu'))
##regularization 2
model.add(Dropout(0.2))
## 0,1,2,3,4 ---- softfax
##output layer
model.add(Dense(units= 1, kernel_initializer= 'uniform', activation = 'sigmoid'))

## compiling the ANN

model.compile(optimizer = 'adam', loss ='binary_crossentropy', metrics = ['accuracy'])

## model
history = model.fit(x_train, y_train, batch_size = 25, epochs = 80, validation_split=0.25)
# Out:
# Epoch 1/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.5438 - loss: 0.6929 - val_accuracy: 0.5556 - val_loss: 0.6928
# Epoch 2/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6975 - loss: 0.6917 - val_accuracy: 0.5556 - val_loss: 0.6925
# Epoch 3/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7285 - loss: 0.6903 - val_accuracy: 0.5556 - val_loss: 0.6922
# Epoch 4/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7382 - loss: 0.6888 - val_accuracy: 0.5556 - val_loss: 0.6919
# Epoch 5/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6912 - loss: 0.6885 - val_accuracy: 0.5556 - val_loss: 0.6916
# Epoch 6/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7155 - loss: 0.6868 - val_accuracy: 0.5556 - val_loss: 0.6913
# Epoch 7/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7250 - loss: 0.6852 - val_accuracy: 0.5556 - val_loss: 0.6909
# Epoch 8/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6740 - loss: 0.6856 - val_accuracy: 0.5556 - val_loss: 0.6904
# Epoch 9/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7115 - loss: 0.6827 - val_accuracy: 0.5556 - val_loss: 0.6897
# Epoch 10/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7263 - loss: 0.6802 - val_accuracy: 0.5556 - val_loss: 0.6886
# Epoch 11/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7049 - loss: 0.6779 - val_accuracy: 0.5556 - val_loss: 0.6868
# Epoch 12/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7223 - loss: 0.6733 - val_accuracy: 0.5556 - val_loss: 0.6842
# Epoch 13/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7334 - loss: 0.6682 - val_accuracy: 0.5556 - val_loss: 0.6801
# Epoch 14/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6914 - loss: 0.6600 - val_accuracy: 0.5556 - val_loss: 0.6743
# Epoch 15/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7267 - loss: 0.6435 - val_accuracy: 0.5556 - val_loss: 0.6661
# Epoch 16/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6991 - loss: 0.6364 - val_accuracy: 0.5556 - val_loss: 0.6554
# Epoch 17/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7434 - loss: 0.6137 - val_accuracy: 0.5556 - val_loss: 0.6417
# Epoch 18/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7221 - loss: 0.6080 - val_accuracy: 0.5556 - val_loss: 0.6258
# Epoch 19/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7420 - loss: 0.5770 - val_accuracy: 0.5556 - val_loss: 0.6088
# Epoch 20/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7012 - loss: 0.5529 - val_accuracy: 0.5556 - val_loss: 0.5907
# Epoch 21/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7114 - loss: 0.5382 - val_accuracy: 0.5556 - val_loss: 0.5743
# Epoch 22/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7440 - loss: 0.5090 - val_accuracy: 0.5556 - val_loss: 0.5600
# Epoch 23/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7549 - loss: 0.4725 - val_accuracy: 0.5556 - val_loss: 0.5501
# Epoch 24/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7599 - loss: 0.4593 - val_accuracy: 0.5556 - val_loss: 0.5453
# Epoch 25/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7209 - loss: 0.4968 - val_accuracy: 0.5556 - val_loss: 0.5432
# Epoch 26/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6915 - loss: 0.4362 - val_accuracy: 0.5556 - val_loss: 0.5434
# Epoch 27/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6895 - loss: 0.4527 - val_accuracy: 0.5556 - val_loss: 0.5464
# Epoch 28/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7011 - loss: 0.4384 - val_accuracy: 0.5556 - val_loss: 0.5508
# Epoch 29/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7199 - loss: 0.4028 - val_accuracy: 0.5556 - val_loss: 0.5532
# Epoch 30/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7324 - loss: 0.4254 - val_accuracy: 0.5556 - val_loss: 0.5562
# Epoch 31/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7095 - loss: 0.4251 - val_accuracy: 0.5556 - val_loss: 0.5630
# Epoch 32/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7266 - loss: 0.4007 - val_accuracy: 0.5556 - val_loss: 0.5709
# Epoch 33/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7363 - loss: 0.4268 - val_accuracy: 0.5556 - val_loss: 0.5774
# Epoch 34/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6940 - loss: 0.3759 - val_accuracy: 0.5556 - val_loss: 0.5835
# Epoch 35/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6985 - loss: 0.4079 - val_accuracy: 0.5556 - val_loss: 0.5865
# Epoch 36/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7297 - loss: 0.3903 - val_accuracy: 0.5556 - val_loss: 0.5887
# Epoch 37/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7236 - loss: 0.3711 - val_accuracy: 0.5556 - val_loss: 0.5929
# Epoch 38/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7226 - loss: 0.3558 - val_accuracy: 0.5556 - val_loss: 0.5980
# Epoch 39/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7497 - loss: 0.3590 - val_accuracy: 0.5556 - val_loss: 0.5988
# Epoch 40/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7089 - loss: 0.3638 - val_accuracy: 0.5556 - val_loss: 0.6005
# Epoch 41/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6897 - loss: 0.3718 - val_accuracy: 0.5556 - val_loss: 0.5970
# Epoch 42/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7275 - loss: 0.3766 - val_accuracy: 0.5556 - val_loss: 0.5966
# Epoch 43/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7074 - loss: 0.3715 - val_accuracy: 0.5556 - val_loss: 0.5991
# Epoch 44/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7208 - loss: 0.4153 - val_accuracy: 0.5556 - val_loss: 0.6002
# Epoch 45/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7312 - loss: 0.3631 - val_accuracy: 0.5556 - val_loss: 0.6049
# Epoch 46/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7304 - loss: 0.3431 - val_accuracy: 0.5556 - val_loss: 0.6157
# Epoch 47/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7031 - loss: 0.3830 - val_accuracy: 0.5556 - val_loss: 0.6223
# Epoch 48/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7240 - loss: 0.3833 - val_accuracy: 0.5556 - val_loss: 0.6256
# Epoch 49/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7002 - loss: 0.4016 - val_accuracy: 0.5556 - val_loss: 0.6317
# Epoch 50/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7475 - loss: 0.3300 - val_accuracy: 0.5556 - val_loss: 0.6353
# Epoch 51/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7010 - loss: 0.3432 - val_accuracy: 0.5556 - val_loss: 0.6341
# Epoch 52/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7342 - loss: 0.4040 - val_accuracy: 0.5556 - val_loss: 0.6330
# Epoch 53/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7015 - loss: 0.3468 - val_accuracy: 0.5556 - val_loss: 0.6364
# Epoch 54/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7166 - loss: 0.3208 - val_accuracy: 0.5556 - val_loss: 0.6429
# Epoch 55/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6983 - loss: 0.3920 - val_accuracy: 0.5556 - val_loss: 0.6453
# Epoch 56/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6976 - loss: 0.3515 - val_accuracy: 0.5556 - val_loss: 0.6545
# Epoch 57/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7178 - loss: 0.3620 - val_accuracy: 0.5556 - val_loss: 0.6616
# Epoch 58/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6899 - loss: 0.3685 - val_accuracy: 0.5556 - val_loss: 0.6681
# Epoch 59/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7271 - loss: 0.3670 - val_accuracy: 0.5556 - val_loss: 0.6712
# Epoch 60/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7183 - loss: 0.3442 - val_accuracy: 0.5556 - val_loss: 0.6730
# Epoch 61/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6947 - loss: 0.3417 - val_accuracy: 0.5556 - val_loss: 0.6741
# Epoch 62/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7000 - loss: 0.3652 - val_accuracy: 0.5556 - val_loss: 0.6726
# Epoch 63/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7044 - loss: 0.3171 - val_accuracy: 0.5556 - val_loss: 0.6754
# Epoch 64/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6755 - loss: 0.3821 - val_accuracy: 0.5556 - val_loss: 0.6690
# Epoch 65/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7279 - loss: 0.3218 - val_accuracy: 0.5556 - val_loss: 0.6698
# Epoch 66/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7420 - loss: 0.3087 - val_accuracy: 0.5556 - val_loss: 0.6662
# Epoch 67/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7347 - loss: 0.3513 - val_accuracy: 0.7778 - val_loss: 0.6671
# Epoch 68/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8889 - loss: 0.3155 - val_accuracy: 0.7778 - val_loss: 0.6726
# Epoch 69/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9106 - loss: 0.2973 - val_accuracy: 0.7778 - val_loss: 0.6824
# Epoch 70/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9138 - loss: 0.3155 - val_accuracy: 0.7778 - val_loss: 0.6902
# Epoch 71/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8890 - loss: 0.3064 - val_accuracy: 0.7778 - val_loss: 0.7011
# Epoch 72/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8981 - loss: 0.3251 - val_accuracy: 0.7778 - val_loss: 0.7118
# Epoch 73/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9261 - loss: 0.2879 - val_accuracy: 0.7778 - val_loss: 0.7245
# Epoch 74/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8955 - loss: 0.3027 - val_accuracy: 0.7778 - val_loss: 0.7360
# Epoch 75/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9126 - loss: 0.2635 - val_accuracy: 0.7778 - val_loss: 0.7475
# Epoch 76/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9037 - loss: 0.3109 - val_accuracy: 0.7778 - val_loss: 0.7536
# Epoch 77/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9071 - loss: 0.3131 - val_accuracy: 0.7778 - val_loss: 0.7555
# Epoch 78/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9043 - loss: 0.2902 - val_accuracy: 0.7778 - val_loss: 0.7542
# Epoch 79/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9270 - loss: 0.2818 - val_accuracy: 0.7778 - val_loss: 0.7635
# Epoch 80/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9258 - loss: 0.2955 - val_accuracy: 0.7778 - val_loss: 0.7754

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy is', val_accuracy*100))
# Out:
# val_accuracy is: 59.44%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Predicting the test set results
y_pred = model.predict(x_test)
y_pred = np.where(y_pred > 0.4, 1, 0)
np.set_printoptions()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot = True, annot_kws = {'size':25})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85        82
#            1       0.67      0.68      0.68        38
#
#     accuracy                           0.79       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.79      0.79      0.79       120

# %%
## save the ann model
model.save('heart_disease.keras')
