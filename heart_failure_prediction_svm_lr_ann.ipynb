# %%
## import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score

## neural network library
from keras.models import Sequential
from keras.layers import Dense, Dropout
from mlxtend.plotting import plot_confusion_matrix
import pickle

# %%
## load data
dfheart = pd.read_csv("heart_failure_clinical_records_dataset.csv")
dfheart.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
## info for missing value and data type
dfheart.info()

## all variables contain no null value but complete
## all variable values are numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
## Basic statistics summary of all variables in dataset
dfheart.describe()

## Age group covering from 40 to 95, missing youth
## mean Sex > 0.5, 14.88% more male interviewees
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
## countplot on all dummy variables
fig, ax = plt.subplots(2,3,figsize=(14,10))
sns.countplot(ax=ax[0,0],data=dfheart, x=dfheart["anaemia"],hue="DEATH_EVENT",palette=["blue","red"])
ax[0,0].legend(['Alive', 'Dead'])
sns.countplot(ax=ax[0,1],data=dfheart, x=dfheart["diabetes"],hue="DEATH_EVENT",palette=["blue","red"])
ax[0,1].legend(['Alive', 'Dead'])
sns.countplot(ax=ax[0,2],data=dfheart, x=dfheart["high_blood_pressure"],hue="DEATH_EVENT",palette=["blue","red"])
ax[0,2].legend(['Alive', 'Dead'])
sns.countplot(ax=ax[1,0],data=dfheart, x=dfheart["DEATH_EVENT"],palette=["blue","red"])
sns.countplot(ax=ax[1,1],data=dfheart, x=dfheart["sex"],hue="DEATH_EVENT",palette=["blue","red"])
ax[1,1].legend(['Alive', 'Dead'])
sns.countplot(ax=ax[1,2],data=dfheart, x=dfheart["smoking"],hue="DEATH_EVENT",palette=["blue","red"])
ax[1,2].legend(['Alive', 'Dead'])
ax[0,0].bar_label(ax[0,0].containers[0])
ax[0,0].bar_label(ax[0,0].containers[1])
ax[0,1].bar_label(ax[0,1].containers[0])
ax[0,1].bar_label(ax[0,1].containers[1])
ax[0,2].bar_label(ax[0,2].containers[0])
ax[0,2].bar_label(ax[0,2].containers[1])
ax[1,0].bar_label(ax[1,0].containers[0])
ax[1,1].bar_label(ax[1,1].containers[0])
ax[1,1].bar_label(ax[1,1].containers[1])
ax[1,2].bar_label(ax[1,2].containers[0])
ax[1,2].bar_label(ax[1,2].containers[1])
# Out:
# C:\Users\aferg\AppData\Local\Temp\ipykernel_23980\1617931097.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax[1,0],data=dfheart, x=dfheart["DEATH_EVENT"],palette=["blue","red"])
# [Text(0, 0, '66'), Text(0, 0, '30')]

# %%
## Correlation Matrix
mt = dfheart.corr()
print(mt)
fig, ax=plt.subplots(figsize=(16,9))
sns.heatmap(mt, annot=True, square=False)
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.101012           0.060098             0.093289
# anaemia                  -0.012729           0.031557             0.038182
# creatinine_phosphokinase -0.009639          -0.044080            -0.070590
# diabetes                  1.000000          -0.004850            -0.012732
# ejection_fraction        -0.004850           1.000000             0.024445
# high_blood_pressure      -0.012732           0.024445             1.000000
# platelets                 0.092193           0.072177             0.049963
# serum_creatinine         -0.046975          -0.011302            -0.004935
# serum_sodium             -0.089551           0.175902             0.037109
# sex                      -0.157730          -0.148386            -0.104615
# smoking                  -0.147173          -0.067315            -0.055711
# time                      0.033726           0.041729            -0.196439
# DEATH_EVENT              -0.001943          -0.268603             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052354          0.159187     -0.045966  0.065430
# anaemia                   -0.043786          0.052174      0.041882 -0.094769
# creatinine_phosphokinase   0.024463         -0.016408      0.059550  0.079791
# diabetes                   0.092193         -0.046975     -0.089551 -0.157730
# ejection_fraction          0.072177         -0.011302      0.175902 -0.148386
# high_blood_pressure        0.049963         -0.004935      0.037109 -0.104615
# platelets                  1.000000         -0.041198      0.062125 -0.125120
# serum_creatinine          -0.041198          1.000000     -0.189095  0.006970
# serum_sodium               0.062125         -0.189095      1.000000 -0.027566
# sex                       -0.125120          0.006970     -0.027566  1.000000
# smoking                    0.028234         -0.027414      0.004813  0.445892
# time                       0.010514         -0.149315      0.087640 -0.015608
# DEATH_EVENT               -0.049139          0.294278     -0.195204 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.018668 -0.224068     0.253729
# anaemia                  -0.107290 -0.141414     0.066270
# creatinine_phosphokinase  0.002421 -0.009346     0.062728
# diabetes                 -0.147173  0.033726    -0.001943
# ejection_fraction        -0.067315  0.041729    -0.268603
# high_blood_pressure      -0.055711 -0.196439     0.079351
# platelets                 0.028234  0.010514    -0.049139
# serum_creatinine         -0.027414 -0.149315     0.294278
# serum_sodium              0.004813  0.087640    -0.195204
# sex                       0.445892 -0.015608    -0.004316
# smoking                   1.000000 -0.022839    -0.012623
# time                     -0.022839  1.000000    -0.526964
# DEATH_EVENT              -0.012623 -0.526964     1.000000
# <Axes: >

# %%
## Visualise the population age distribution between the alive and the dead
plt.figure(figsize=(16,8))
ax = sns.histplot(dfheart["age"][dfheart.DEATH_EVENT == 0], color="blue", kde=True), sns.histplot(dfheart["age"][dfheart.DEATH_EVENT == 1], color="red", kde=True)
plt.legend(['Alive', 'Dead'])
plt.title('Age Distribution for Population Alive and Dead')

## Older people are more likely to be dead than alive, the younger ones are in opposite situation
## however, the age data in general is not normally distributed given that it is right-skewed with big left tail, due to missing youth population data and extremely old outliers.
# Out:
# Text(0.5, 1.0, 'Age Distribution for Population Alive and Dead')

# %%
## Visualise the population follow-up time distribution between the alive and the dead
plt.figure(figsize=(16,8))
ax = sns.histplot(dfheart["time"][dfheart.DEATH_EVENT == 0], color="blue", kde=True), sns.histplot(dfheart["time"][dfheart.DEATH_EVENT == 1], color="red", kde=True)
plt.legend(['Alive', 'Dead'])
plt.title('Follow-up Time Distribution for Population Alive and Dead')

## Death cases are more likely to be rapid.
# Out:
# Text(0.5, 1.0, 'Follow-up Time Distribution for Population Alive and Dead')

# %%
## boxplot on all non-dummy variables
fig, ax = plt.subplots(3,3,figsize=(18,10))
sns.swarmplot(ax=ax[0,0], x=dfheart["DEATH_EVENT"], y=dfheart["age"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[0,0], x=dfheart["DEATH_EVENT"], y=dfheart["age"])
sns.swarmplot(ax=ax[0,1], x=dfheart["DEATH_EVENT"], y=dfheart["creatinine_phosphokinase"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[0,1], x=dfheart["DEATH_EVENT"], y=dfheart["creatinine_phosphokinase"])
sns.swarmplot(ax=ax[0,2], x=dfheart["DEATH_EVENT"], y=dfheart["ejection_fraction"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[0,2], x=dfheart["DEATH_EVENT"], y=dfheart["ejection_fraction"])
sns.swarmplot(ax=ax[1,0], x=dfheart["DEATH_EVENT"], y=dfheart["platelets"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[1,0], x=dfheart["DEATH_EVENT"], y=dfheart["platelets"])
sns.swarmplot(ax=ax[1,1], x=dfheart["DEATH_EVENT"], y=dfheart["serum_creatinine"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[1,1], x=dfheart["DEATH_EVENT"], y=dfheart["serum_creatinine"])
sns.swarmplot(ax=ax[1,2], x=dfheart["DEATH_EVENT"], y=dfheart["serum_sodium"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[1,2], x=dfheart["DEATH_EVENT"], y=dfheart["serum_sodium"])
sns.swarmplot(ax=ax[2,1], x=dfheart["DEATH_EVENT"], y=dfheart["time"], color="black",alpha=0.7)
sns.boxenplot(ax=ax[2,1], x=dfheart["DEATH_EVENT"], y=dfheart["time"])

## Exisintg outliers in most variables, but not significant enough to affect the predictions given sample size and outlier numbers and values
## Need to scale given non-normal distribution in some variables
# Out:
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 34.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 35.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='DEATH_EVENT', ylabel='time'>
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
## defining independent and dependent variables
x=dfheart.drop(["DEATH_EVENT"],axis=1)
y=dfheart["DEATH_EVENT"]

# %%
## Scale up the data for prediction models
cols = list(x.columns)
scaler = StandardScaler()
scale_x = scaler.fit_transform(x)
dfscale_x = pd.DataFrame(scale_x, columns= cols)
dfscale_x.describe()
# Out:
#                 age       anaemia  creatinine_phosphokinase      diabetes  \
# count  2.990000e+02  2.990000e+02                299.000000  2.990000e+02
# mean   5.703353e-16  1.009969e-16                  0.000000  9.060014e-17
# std    1.001676e+00  1.001676e+00                  1.001676  1.001676e+00
# min   -1.754448e+00 -8.711048e-01                 -0.576918 -8.475794e-01
# 25%   -8.281242e-01 -8.711048e-01                 -0.480393 -8.475794e-01
# 50%   -7.022315e-02 -8.711048e-01                 -0.342574 -8.475794e-01
# 75%    7.718891e-01  1.147968e+00                  0.000166  1.179830e+00
# max    2.877170e+00  1.147968e+00                  7.514640  1.179830e+00
#
#        ejection_fraction  high_blood_pressure     platelets  serum_creatinine  \
# count       2.990000e+02           299.000000  2.990000e+02      2.990000e+02
# mean       -3.267546e-17             0.000000  7.723291e-17      1.425838e-16
# std         1.001676e+00             1.001676  1.001676e+00      1.001676e+00
# min        -2.038387e+00            -0.735688 -2.440155e+00     -8.655094e-01
# 25%        -6.841802e-01            -0.735688 -5.208700e-01     -4.782047e-01
# 50%        -7.076750e-03            -0.735688 -1.390846e-02     -2.845524e-01
# 75%         5.853888e-01             1.359272  4.111199e-01      5.926150e-03
# max         3.547716e+00             1.359272  6.008180e+00      7.752020e+00
#
#        serum_sodium           sex       smoking          time
# count  2.990000e+02  2.990000e+02  2.990000e+02  2.990000e+02
# mean  -8.673849e-16 -8.911489e-18 -1.188199e-17 -1.901118e-16
# std    1.001676e+00  1.001676e+00  1.001676e+00  1.001676e+00
# min   -5.363206e+00 -1.359272e+00 -6.876819e-01 -1.629502e+00
# 25%   -5.959961e-01 -1.359272e+00 -6.876819e-01 -7.389995e-01
# 50%    8.503384e-02  7.356882e-01 -6.876819e-01 -1.969543e-01
# 75%    7.660638e-01  7.356882e-01  1.454161e+00  9.387595e-01
# max    2.582144e+00  7.356882e-01  1.454161e+00  1.997038e+00

# %%
## train-test split 
x_train, x_test, y_train,y_test = train_test_split(scale_x,y,test_size=0.4,random_state=23)

# %%
# Instantiating the SVM algorithm 
#Create a SVM Classifier
svm_linear = svm.SVC(kernel='linear')
svm_sigmoid = svm.SVC(kernel='sigmoid') 
svm_rbf = svm.SVC(kernel='rbf') 

# Fitting the model 
svm_linear.fit(x_train, y_train)
svm_sigmoid.fit(x_train, y_train)
svm_rbf.fit(x_train, y_train)

# Predicting the test variables
y_pred_linear = svm_linear.predict(x_test)
y_pred_sigmoid = svm_sigmoid.predict(x_test)
y_pred_rbf = svm_rbf.predict(x_test)

# Getting the score 
print("Linear Kernel Accuracy:",metrics.accuracy_score(y_test, y_pred_linear))
print("Sigmoid kernel Accuracy:",metrics.accuracy_score(y_test, y_pred_sigmoid))
print("rbf kernelAccuracy:",metrics.accuracy_score(y_test, y_pred_rbf))
# Out:
# Linear Kernel Accuracy: 0.7916666666666666
# Sigmoid kernel Accuracy: 0.8083333333333333
# rbf kernelAccuracy: 0.7833333333333333

# %%
## make a dataframe prediction for linear kernel
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_linear})
# Out:
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          1
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
## make a dataframe prediction for linear kernel
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_sigmoid})
# Out:
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          0
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
## make a dataframe prediction for linear kernel
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_rbf})
# Out:
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          1
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
## confussion matrix for the kernels
conf_mat_linear = confusion_matrix(y_test, y_pred_linear)
conf_mat_sigmoid = confusion_matrix(y_test, y_pred_sigmoid)
conf_mat_rbf = confusion_matrix(y_test, y_pred_rbf)

print(conf_mat_linear)
print(conf_mat_sigmoid)
print(conf_mat_rbf)
# Out:
# [[70 12]
#  [13 25]]
# [[75  7]
#  [16 22]]
# [[74  8]
#  [18 20]]

# %%
sns.heatmap(conf_mat_linear, annot=True, fmt='.0f')
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred_linear))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85        82
#            1       0.68      0.66      0.67        38
#
#     accuracy                           0.79       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.79      0.79      0.79       120

# %%
auc = roc_auc_score(y_test, y_pred_linear)
print('AUC: %f' %auc)
# Out:
# AUC: 0.755777

# %%
fpr, tpr = roc_curve(y_test, y_pred_linear)[0:2]

plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()

# %%
# Build a logiReg Model
model_lr = LogisticRegression(random_state=0, solver='lbfgs', max_iter=100)
model_lr.fit(x_train, y_train)
y_pred_lr = model_lr.predict(x_test)
print(model_lr.coef_)
## accuracy score
print(accuracy_score(y_test,y_pred_lr))
## confusion matrix
mat = confusion_matrix(y_test, y_pred_lr)
print(mat)
print(classification_report(y_test,y_pred_lr))
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr})
# Out:
# [[ 0.5559466   0.08194236  0.3764469   0.1398406  -0.85338447  0.04650698
#   -0.34281474  1.01912125 -0.2731351  -0.41714128 -0.17910547 -1.34243291]]
# 0.775
# [[71 11]
#  [16 22]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84        82
#            1       0.67      0.58      0.62        38
#
#     accuracy                           0.78       120
#    macro avg       0.74      0.72      0.73       120
# weighted avg       0.77      0.78      0.77       120
#      Actual  Predicted
# 184       1          0
# 110       1          0
# 159       0          0
# 221       0          0
# 14        0          1
# ..      ...        ...
# 234       0          0
# 225       0          0
# 267       0          0
# 200       0          0
# 2         1          1
#
# [120 rows x 2 columns]

# %%
fpr, tpr = roc_curve(y_test, y_pred_lr)[0:2]

plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()

# %%
## Neural Network
## initialise the NN
model = Sequential()

##set up the layers
## input layer
model.add(Dense(units= 50, kernel_initializer= 'uniform', activation = 'relu', input_dim = 12)) # 50 neurons, initialiser gives starting weights - uniform gives random in distribution [0,1]
## hidden layer 1 
model.add(Dense(units= 20, kernel_initializer= 'uniform', activation = 'relu')) # other initialisers are HeNormal, HeUniform, GlorotUniform and GlorotNormal for He and Xavier initialisers
##regularization 1
model.add(Dropout(0.4)) # setting 40% of the data to zero to avoid overfitting
## hidden layer 2
model.add(Dense(units= 4, kernel_initializer= 'uniform', activation = 'relu')) # activation function is relu here other options are sigmoid, softmax, leaky relu etc.
## regularization 2
model.add(Dropout(0.2)) # another regularisation to avoid overfitting
## output layer - 1 neuron here because output is a probability i.e. binary classification 1 or 0. But for multiple classes, the units will be the number of classes
# multiple classes classification activation function should be softmax
model.add(Dense(units= 1, kernel_initializer= 'uniform', activation = 'sigmoid')) # dense means every neuron is connected to every neuron in the next layer

## compiling the ANN
# binary crossentropy for loss function for binary classification. For a regression problem, loss function can be mean squared error. For multiple classes, categorical cross entropy
model.compile(optimizer = 'adam', loss ='binary_crossentropy', metrics = ['accuracy'])

## model - epochs means number of iterations of forward and backwards propogation during training. Batch size means how many iterations before weights are updated. 
# validation split means we use 25% of the training data for monitor the performance of the model to avoid overfitting.
# can also use test data instead by writing validation_data = (x_test, y_test) if you dont have much data
# can look into early stopping to have a large number of epochs and only stop once the network stops learning
history = model.fit(x_train, y_train, batch_size = 25, epochs = 80, validation_split=0.25)
# Out:
# Epoch 1/80
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6029 - loss: 0.6928 - val_accuracy: 0.5556 - val_loss: 0.6928
# Epoch 2/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7166 - loss: 0.6916 - val_accuracy: 0.5556 - val_loss: 0.6925
# Epoch 3/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7176 - loss: 0.6903 - val_accuracy: 0.5556 - val_loss: 0.6922
# Epoch 4/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7155 - loss: 0.6890 - val_accuracy: 0.5556 - val_loss: 0.6918
# Epoch 5/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7343 - loss: 0.6870 - val_accuracy: 0.5556 - val_loss: 0.6914
# Epoch 6/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7367 - loss: 0.6855 - val_accuracy: 0.5556 - val_loss: 0.6909
# Epoch 7/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6808 - loss: 0.6859 - val_accuracy: 0.5556 - val_loss: 0.6902
# Epoch 8/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6924 - loss: 0.6832 - val_accuracy: 0.5556 - val_loss: 0.6892
# Epoch 9/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7022 - loss: 0.6808 - val_accuracy: 0.5556 - val_loss: 0.6878
# Epoch 10/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7313 - loss: 0.6757 - val_accuracy: 0.5556 - val_loss: 0.6858
# Epoch 11/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7164 - loss: 0.6723 - val_accuracy: 0.5556 - val_loss: 0.6828
# Epoch 12/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7218 - loss: 0.6655 - val_accuracy: 0.5556 - val_loss: 0.6784
# Epoch 13/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7425 - loss: 0.6556 - val_accuracy: 0.5556 - val_loss: 0.6723
# Epoch 14/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6881 - loss: 0.6578 - val_accuracy: 0.5556 - val_loss: 0.6645
# Epoch 15/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7423 - loss: 0.6304 - val_accuracy: 0.5556 - val_loss: 0.6535
# Epoch 16/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7078 - loss: 0.6246 - val_accuracy: 0.6000 - val_loss: 0.6398
# Epoch 17/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7742 - loss: 0.5964 - val_accuracy: 0.7111 - val_loss: 0.6237
# Epoch 18/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8250 - loss: 0.5748 - val_accuracy: 0.7333 - val_loss: 0.6039
# Epoch 19/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8041 - loss: 0.5605 - val_accuracy: 0.7333 - val_loss: 0.5840
# Epoch 20/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8733 - loss: 0.5243 - val_accuracy: 0.7333 - val_loss: 0.5618
# Epoch 21/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8384 - loss: 0.5198 - val_accuracy: 0.7333 - val_loss: 0.5411
# Epoch 22/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8687 - loss: 0.4484 - val_accuracy: 0.8000 - val_loss: 0.5180
# Epoch 23/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8300 - loss: 0.4588 - val_accuracy: 0.8222 - val_loss: 0.4972
# Epoch 24/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8983 - loss: 0.4247 - val_accuracy: 0.8222 - val_loss: 0.4792
# Epoch 25/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8800 - loss: 0.4420 - val_accuracy: 0.8222 - val_loss: 0.4626
# Epoch 26/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8657 - loss: 0.4088 - val_accuracy: 0.8222 - val_loss: 0.4522
# Epoch 27/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8269 - loss: 0.4436 - val_accuracy: 0.8222 - val_loss: 0.4458
# Epoch 28/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8373 - loss: 0.4061 - val_accuracy: 0.8222 - val_loss: 0.4418
# Epoch 29/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8641 - loss: 0.3967 - val_accuracy: 0.8222 - val_loss: 0.4359
# Epoch 30/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8903 - loss: 0.3754 - val_accuracy: 0.8222 - val_loss: 0.4356
# Epoch 31/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8736 - loss: 0.3411 - val_accuracy: 0.8222 - val_loss: 0.4314
# Epoch 32/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8583 - loss: 0.4101 - val_accuracy: 0.8000 - val_loss: 0.4277
# Epoch 33/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8554 - loss: 0.3900 - val_accuracy: 0.8000 - val_loss: 0.4276
# Epoch 34/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8492 - loss: 0.4025 - val_accuracy: 0.8000 - val_loss: 0.4284
# Epoch 35/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8638 - loss: 0.3764 - val_accuracy: 0.8000 - val_loss: 0.4316
# Epoch 36/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8618 - loss: 0.3808 - val_accuracy: 0.8000 - val_loss: 0.4322
# Epoch 37/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8727 - loss: 0.3541 - val_accuracy: 0.8000 - val_loss: 0.4323
# Epoch 38/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8866 - loss: 0.3781 - val_accuracy: 0.8222 - val_loss: 0.4256
# Epoch 39/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8853 - loss: 0.3864 - val_accuracy: 0.8222 - val_loss: 0.4219
# Epoch 40/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8705 - loss: 0.4076 - val_accuracy: 0.8222 - val_loss: 0.4217
# Epoch 41/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9127 - loss: 0.3409 - val_accuracy: 0.8222 - val_loss: 0.4240
# Epoch 42/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9327 - loss: 0.3603 - val_accuracy: 0.8222 - val_loss: 0.4292
# Epoch 43/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9138 - loss: 0.2986 - val_accuracy: 0.8222 - val_loss: 0.4323
# Epoch 44/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8899 - loss: 0.3575 - val_accuracy: 0.8000 - val_loss: 0.4366
# Epoch 45/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9080 - loss: 0.3467 - val_accuracy: 0.8000 - val_loss: 0.4354
# Epoch 46/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9190 - loss: 0.3192 - val_accuracy: 0.8000 - val_loss: 0.4362
# Epoch 47/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9079 - loss: 0.3206 - val_accuracy: 0.8000 - val_loss: 0.4314
# Epoch 48/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9269 - loss: 0.2905 - val_accuracy: 0.8222 - val_loss: 0.4317
# Epoch 49/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9030 - loss: 0.3008 - val_accuracy: 0.8222 - val_loss: 0.4328
# Epoch 50/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8790 - loss: 0.3574 - val_accuracy: 0.8000 - val_loss: 0.4334
# Epoch 51/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9142 - loss: 0.2670 - val_accuracy: 0.8000 - val_loss: 0.4346
# Epoch 52/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8742 - loss: 0.3240 - val_accuracy: 0.8000 - val_loss: 0.4364
# Epoch 53/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9254 - loss: 0.3363 - val_accuracy: 0.8000 - val_loss: 0.4399
# Epoch 54/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8834 - loss: 0.2929 - val_accuracy: 0.8000 - val_loss: 0.4417
# Epoch 55/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9227 - loss: 0.3128 - val_accuracy: 0.8000 - val_loss: 0.4463
# Epoch 56/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9311 - loss: 0.2830 - val_accuracy: 0.8000 - val_loss: 0.4423
# Epoch 57/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9330 - loss: 0.2777 - val_accuracy: 0.8000 - val_loss: 0.4403
# Epoch 58/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9177 - loss: 0.3669 - val_accuracy: 0.8000 - val_loss: 0.4364
# Epoch 59/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9293 - loss: 0.2534 - val_accuracy: 0.8000 - val_loss: 0.4332
# Epoch 60/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9460 - loss: 0.2690 - val_accuracy: 0.8000 - val_loss: 0.4314
# Epoch 61/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9437 - loss: 0.2204 - val_accuracy: 0.8000 - val_loss: 0.4320
# Epoch 62/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9713 - loss: 0.2386 - val_accuracy: 0.8000 - val_loss: 0.4336
# Epoch 63/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9376 - loss: 0.2842 - val_accuracy: 0.8000 - val_loss: 0.4367
# Epoch 64/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9574 - loss: 0.2267 - val_accuracy: 0.8000 - val_loss: 0.4389
# Epoch 65/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9473 - loss: 0.3149 - val_accuracy: 0.8000 - val_loss: 0.4392
# Epoch 66/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9317 - loss: 0.3272 - val_accuracy: 0.8000 - val_loss: 0.4406
# Epoch 67/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9393 - loss: 0.2703 - val_accuracy: 0.8000 - val_loss: 0.4391
# Epoch 68/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9392 - loss: 0.2929 - val_accuracy: 0.8000 - val_loss: 0.4367
# Epoch 69/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9647 - loss: 0.2457 - val_accuracy: 0.8000 - val_loss: 0.4333
# Epoch 70/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9189 - loss: 0.3070 - val_accuracy: 0.8222 - val_loss: 0.4313
# Epoch 71/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9355 - loss: 0.2959 - val_accuracy: 0.8222 - val_loss: 0.4335
# Epoch 72/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8907 - loss: 0.3210 - val_accuracy: 0.8222 - val_loss: 0.4345
# Epoch 73/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9415 - loss: 0.2667 - val_accuracy: 0.8222 - val_loss: 0.4347
# Epoch 74/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9242 - loss: 0.2854 - val_accuracy: 0.8222 - val_loss: 0.4336
# Epoch 75/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9261 - loss: 0.2932 - val_accuracy: 0.8222 - val_loss: 0.4342
# Epoch 76/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9136 - loss: 0.2460 - val_accuracy: 0.8222 - val_loss: 0.4335
# Epoch 77/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8987 - loss: 0.3598 - val_accuracy: 0.8222 - val_loss: 0.4353
# Epoch 78/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9647 - loss: 0.2735 - val_accuracy: 0.8222 - val_loss: 0.4316
# Epoch 79/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9164 - loss: 0.3786 - val_accuracy: 0.8222 - val_loss: 0.4303
# Epoch 80/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9542 - loss: 0.2670 - val_accuracy: 0.8222 - val_loss: 0.4269

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy is', val_accuracy*100))
# Out:
# val_accuracy is: 75.50%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Predicting the test set results
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.4) # set threshold, everything above 0.4 is 1 and everything below is 0
# can use y_pred = np.where(y_pred > 0.4, 1, 0) instead
np.set_printoptions()
print(y_pred)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]]

# %%
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot = True, annot_kws = {'size':25})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85        82
#            1       0.68      0.66      0.67        38
#
#     accuracy                           0.79       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.79      0.79      0.79       120

# %%
## save the ann model
model.save('heart_disease.keras')
